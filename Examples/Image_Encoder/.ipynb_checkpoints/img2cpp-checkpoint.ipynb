# %%
from fastcore.utils import walk, Path

# %%
p = Path()

# %%
imgpath = p.absolute() / '../../Crossover/Sophia/stills-c/'

# %%
newlines = []

for f in imgpath.ls():
    if f.suffix == '.c':
        lines = f.readlines()
# Out:
# (#15) [Path('/home/jpunkt/Documents/Projekte/2024/New-Talents-Ruhr/Projects/Image_Encoder/../../Crossover/Jan/Font_Images-c/r1.c'),Path('/home/jpunkt/Documents/Projekte/2024/New-Talents-Ruhr/Projects/Image_Encoder/../../Crossover/Jan/Font_Images-c/n2.c'),Path('/home/jpunkt/Documents/Projekte/2024/New-Talents-Ruhr/Projects/Image_Encoder/../../Crossover/Jan/Font_Images-c/k3.c'),Path('/home/jpunkt/Documents/Projekte/2024/New-Talents-Ruhr/Projects/Image_Encoder/../../Crossover/Jan/Font_Images-c/k2.c'),Path('/home/jpunkt/Documents/Projekte/2024/New-Talents-Ruhr/Projects/Image_Encoder/../../Crossover/Jan/Font_Images-c/r4.c'),Path('/home/jpunkt/Documents/Projekte/2024/New-Talents-Ruhr/Projects/Image_Encoder/../../Crossover/Jan/Font_Images-c/k1.c'),Path('/home/jpunkt/Documents/Projekte/2024/New-Talents-Ruhr/Projects/Image_Encoder/../../Crossover/Jan/Font_Images-c/n3.c'),Path('/home/jpunkt/Documents/Projekte/2024/New-Talents-Ruhr/Projects/Image_Encoder/../../Crossover/Jan/Font_Images-c/n1.c'),Path('/home/jpunkt/Documents/Projekte/2024/New-Talents-Ruhr/Projects/Image_Encoder/../../Crossover/Jan/Font_Images-c/r2.c'),Path('/home/jpunkt/Documents/Projekte/2024/New-Talents-Ruhr/Projects/Image_Encoder/../../Crossover/Jan/Font_Images-c/k4.c')...]

# %%
f = imgpath.ls()[0]

# %%
int(f.stem[-5:])
# Out:
# 86

# %%
['{\n']+[line for line in f.readlines() if not (line.startswith('//') or line.startswith('\n'))][1:-1]+['}\n']
# Out:
# ['{\n',
#  '0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0061, 0x0000, 0x0000, 0x0000, 0x0000,   // 0x0010 (16) pixels\n',
#  '0x0000, 0x0000, 0x0000, 0x00E3, 0x0021, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0126, 0x0126, 0x0000, 0x0000, 0x0000,   // 0x0020 (32) pixels\n',
#  '0x0000, 0x0000, 0x00E3, 0x053A, 0x02AF, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x5EFF, 0x2EFF, 0x0000, 0x0000, 0x0000,   // 0x0030 (48) pixels\n',
#  '0x0000, 0x0000, 0x0063, 0x9F7F, 0xAF7F, 0x020A, 0x0000, 0x0000, 0x0020, 0x0061, 0x0E7F, 0xD7BF, 0xD7BF, 0x1E9F, 0x0001, 0x0061,   // 0x0040 (64) pixels\n',
#  '0x0000, 0x020A, 0x8F7F, 0xDFBF, 0xDFFF, 0xAF9F, 0x05BD, 0x01A8, 0x0063, 0x03B4, 0x7F3F, 0xD7BF, 0xDFFF, 0xB79F, 0x0456, 0x0000,   // 0x0050 (80) pixels\n',
#  '0x0061, 0x00E3, 0x053A, 0xC7BF, 0xDFBF, 0x777F, 0x0000, 0x0000, 0x0000, 0x0000, 0x00A6, 0x8F7F, 0xB79F, 0x053A, 0x0000, 0x0000,   // 0x0060 (96) pixels\n',
#  '0x0000, 0x0020, 0x0020, 0x05BD, 0x36FF, 0x0126, 0x0000, 0x0000, 0x0000, 0x0020, 0x0000, 0x01A8, 0x0330, 0x0063, 0x0000, 0x0000,   // 0x0070 (112) pixels\n',
#  '0x0000, 0x0000, 0x0020, 0x00A4, 0x01A8, 0x00E3, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000,   // 0x0080 (128) pixels\n',
#  '}\n']

# %%
fsorted = {int(f.stem[-5:]):f for f in imgpath.ls() if f.suffix == '.c'}

# %%
text = ['const unsigned short pulse[][128] = {\n',]

# %%
for i in range(max(fsorted.keys())):
    f = fsorted[i]
    lines = ['{ // frame' + f' {i:0d}' + '\n']+[line for line in f.readlines() if not (line.startswith('//') or line.startswith('\n'))][1:-1]+['},\n']
    text += lines
text += ['}\n']

# %%
newfilepath = imgpath / '../pulse.h'

# %%
textstr = ''.join(text)

# %%
textstr
# Out:
# 'const unsigned short pulse[][128] = {\n{ // frame 0\n0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0001, 0x0000, 0x0000, 0x0000, 0x0000,   // 0x0010 (16) pixels\n0x0000, 0x0000, 0x0000, 0x0000, 0x0801, 0x0002, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0002, 0x00AB, 0x00A4, 0x0000, 0x0000,   // 0x0020 (32) pixels\n0x0020, 0x0004, 0x0004, 0x0275, 0x037D, 0x012B, 0x0000, 0x0000, 0x0002, 0x00A6, 0x0131, 0x05FF, 0x0E3F, 0x0131, 0x0000, 0x0000,   // 0x0030 (48) pixels\n0x0006, 0x022F, 0x04BD, 0x0E7F, 0x0E7F, 0x05BF, 0x0006, 0x0000, 0x0020, 0x0131, 0x05FF, 0x0E7F, 0x165F, 0x0E7F, 0x0156, 0x0000,   // 0x0040 (64) pixels\n0x0061, 0x0131, 0x063F, 0x1E9F, 0x1E9F, 0x0E7F, 0x045B, 0x0008, 0x00A4, 0x0275, 0x067F, 0x165F, 0x269F, 0x067F, 0x045E, 0x00A4,   // 0x0050 (80) pixels\n0x0000, 0x0008, 0x0E3F, 0x0E7F, 0x165F, 0x063F, 0x0131, 0x0000, 0x0000, 0x0008, 0x04BD, 0x0E7F, 0x0E7F, 0x05BF, 0x0808, 0x0000,   // 0x0060 (96) pixels\n0x0020, 0x0000, 0x0808, 0x05FF, 0x165F, 0x037A, 0x0006, 0x0000, 0x0001, 0x0000, 0x0801, 0x0275, 0x045E, 0x022F, 0x0021, 0x0000,   // 0x0070 (112) pixels\n0x0000, 0x0000, 0x0063, 0x0088, 0x0131, 0x00A6, 0x0063, 0x0000, 0x0000, 0x0000, 0x0000, 0x0800, 0x00A4, 0x0001, 0x0000, 0x0000,   // 0x0080 (128) pixels\n},\n{ // frame 1\n0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0020, 0x0000, 0x0000, 0x0000, 0x0000,   // 0x0010 (16) pixels\n0x0000, 0x0000, 0x0000, 0x0000, 0x0800, 0x0001, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0002, 0x0006, 0x0004, 0x0000, 0x0000,   // 0x0020 (32) pixels\n0x0000, 0x0002, 0x0002, 0x0131, 0x0156, 0x0008, 0x0000, 0x0000, 0x0002, 0x0063, 0x080B, 0x041D, 0x041D, 0x000E, 0x0000, 0x0000,   // 0x0030 (48) pixels\n0x0004, 0x00AB, 0x0156, 0x053E, 0x05BF, 0x025A, 0x0004, 0x0000, 0x0000, 0x000B, 0x037D, 0x05FF, 0x063E, 0x04DE, 0x000E, 0x0800,   // 0x0040 (64) pixels\n0x0021, 0x000E, 0x037D, 0x063F, 0x063F, 0x059E, 0x0156, 0x0004, 0x0063, 0x000E, 0x04DE, 0x063F, 0x063F, 0x053E, 0x0156, 0x0004,   // 0x0050 (80) pixels\n0x0000, 0x0806, 0x041D, 0x05FF, 0x063E, 0x041D, 0x000E, 0x0000, 0x0000, 0x0004, 0x017A, 0x059E, 0x05FF, 0x025A, 0x0806, 0x0000,   // 0x0060 (96) pixels\n0x0000, 0x0000, 0x1022, 0x02DC, 0x04DE, 0x0156, 0x0002, 0x0000, 0x0001, 0x0000, 0x0000, 0x0131, 0x017A, 0x012B, 0x0001, 0x0000,   // 0x0070 (112) pixels\n0x0000, 0x0000, 0x0021, 0x0006, 0x000B, 0x0004, 0x0061, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0002, 0x0001, 0x0000, 0x0000,   // 0x0080 (128) pixels\n},\n{ // frame 2\n0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000,   // 0x0010 (16) pixels\n0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0001, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0004, 0x0002, 0x0000, 0x0000,   // 0x0020 (32) pixels\n0x0000, 0x0001, 0x0002, 0x000B, 0x000E, 0x0004, 0x0000, 0x0000, 0x0001, 0x0002, 0x0006, 0x017A, 0x0099, 0x0808, 0x0000, 0x0000,   // 0x0030 (48) pixels\n0x0002, 0x0008, 0x0031, 0x025A, 0x02DC, 0x0036, 0x0002, 0x0000, 0x0020, 0x0006, 0x0099, 0x02DC, 0x037D, 0x017A, 0x0808, 0x0000,   // 0x0040 (64) pixels\n0x0001, 0x0806, 0x0099, 0x037D, 0x041D, 0x019B, 0x0031, 0x0002, 0x0002, 0x000B, 0x017A, 0x037D, 0x037D, 0x019B, 0x0031, 0x0002,   // 0x0050 (80) pixels\n0x0000, 0x0002, 0x0099, 0x037D, 0x037D, 0x0099, 0x0806, 0x0000, 0x0000, 0x0002, 0x0031, 0x025A, 0x02DC, 0x0036, 0x0002, 0x0000,   // 0x0060 (96) pixels\n0x0000, 0x0000, 0x0841, 0x0036, 0x019B, 0x000E, 0x0002, 0x0000, 0x0000, 0x0000, 0x0000, 0x000B, 0x0031, 0x0088, 0x0000, 0x0000,   // 0x0070 (112) pixels\n0x0000, 0x0000, 0x0001, 0x0004, 0x0006, 0x0002, 0x0002, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0002, 0x0000, 0x0000, 0x0000,   // 0x0080 (128) pixels\n},\n{ // frame 3\n0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000,   // 0x0010 (16) pixels\n0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x000 ...

# %%
newfilepath.write_text(textstr)
# Out:
# 287918

# %%
for f in imgpath.ls():
    if f.suffix == '.c':
        fsorted[int(f.stem[-5:])] = f
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 5
#       3 for f in imgpath.ls():
#       4     if f.suffix == '.c':
# ----> 5         fsorted[int(f.stem[-5:])] = f
#
# IndexError: list assignment index out of range
