# %%
from fastcore.utils import walk, Path

# %%
p = Path()

# %%
imgpath = p.absolute() / '../../Crossover/Jan/Font_Images-c/'

# %%
f = imgpath.ls()[0]

# %%
f.stem
# Out:
# 'r1'

# %%
int(f.stem[-5:])
# Out:
# 86

# %%
['{\n']+[line for line in f.readlines() if not (line.startswith('//') or line.startswith('\n'))][1:-1]+['}\n']
# Out:
# ['{\n',
#  '0x0000, 0x0000, 0x0000, 0xE71C, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0xFFFF, 0x0000, 0x0000, 0x0000, 0x0000,   // 0x0010 (16) pixels\n',
#  '0x0000, 0x0000, 0x0000, 0xFFFF, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0xFFFF, 0x3186, 0x0000, 0x0000, 0x0000,   // 0x0020 (32) pixels\n',
#  '0x0000, 0x0000, 0x0000, 0x630C, 0xE71C, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0xFFFF, 0x8410, 0x0000, 0x0000, 0x0000,   // 0x0030 (48) pixels\n',
#  '0x0000, 0x0000, 0x0000, 0xFFFF, 0xFFFF, 0x630C, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0xE71C, 0x630C, 0xFFFF, 0x0000, 0x0000,   // 0x0040 (64) pixels\n',
#  '}\n']

# %%
linessorted = {}

for c in ('n','k','r'):
    lineslist = {}
    for i in range(5):
        lineslist[i] = [line for line in f.readlines() if not (line.startswith('//') or line.startswith('\n'))][1:-1]
    linessorted[c] = lineslist

# %%
linessorted
# Out:
# {'n': {0: ['0x3186, 0x8410, 0xAD55, 0x8C51, 0x8410, 0x8410, 0x8410, 0x3186, 0x3186, 0x8410, 0xEF5D, 0xA514, 0x8410, 0xF79E, 0xF79E, 0x3186,   // 0x0010 (16) pixels\n',
#    '0x1082, 0x1082, 0xC618, 0x4A69, 0xB596, 0xD69A, 0x3186, 0x0000, 0x8410, 0x8410, 0xCE79, 0xDEFB, 0xB596, 0x1082, 0x0000, 0x0000,   // 0x0020 (32) pixels\n',
#    '0x8410, 0x8410, 0xF7BE, 0xEF5D, 0x2104, 0x0000, 0x738E, 0x738E, 0x1082, 0x1082, 0xC638, 0xA514, 0xFFFF, 0x8410, 0x9492, 0x8410,   // 0x0030 (48) pixels\n',
#    '0x3186, 0x8410, 0xE71C, 0x4208, 0x2104, 0xC618, 0xFFFF, 0x8410, 0x3186, 0x8410, 0x8410, 0x1082, 0x0000, 0x0000, 0x528A, 0x3186,   // 0x0040 (64) pixels\n'],
#   1: ['0x3186, 0x8410, 0xAD55, 0x8C51, 0x8410, 0x8410, 0x8410, 0x3186, 0x3186, 0x8410, 0xEF5D, 0xA514, 0x8410, 0xF79E, 0xF79E, 0x3186,   // 0x0010 (16) pixels\n',
#    '0x1082, 0x1082, 0xC618, 0x4A69, 0xB596, 0xD69A, 0x3186, 0x0000, 0x8410, 0x8410, 0xCE79, 0xDEFB, 0xB596, 0x1082, 0x0000, 0x0000,   // 0x0020 (32) pixels\n',
# ...

# %%
text = []

# %%
for c in ('n','k','r'):
    lines = [f'const unsigned short {c}[][64]'+' = {\n',]
    for i in range(5):
        f = imgpath / f'{c}{i+1}.c'
        lines += ['{ // frame' + f' {i:0d}' + '\n']+[line for line in f.readlines() if not (line.startswith('//') or line.startswith('\n'))][1:-1]+['},\n']
    lines += ['};\n']
    text += lines

# %%
text
# Out:
# ['const unsigned short n[][64] = {\n',
#  '{ // frame 0\n',
#  '0x0000, 0x0000, 0x0000, 0xE71C, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0xFFFF, 0xE71C, 0x3186, 0x0000, 0x0000,   // 0x0010 (16) pixels\n',
#  '0x0000, 0x0000, 0x0000, 0xFFFF, 0x630C, 0xF79E, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x630C, 0x0000, 0xFFFF, 0x0000, 0x0000,   // 0x0020 (32) pixels\n',
#  '0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0xFFFF, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0xFFFF, 0x0000, 0x0000,   // 0x0030 (48) pixels\n',
#  '0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0xFFFF, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0xE71C, 0x0000, 0x0000,   // 0x0040 (64) pixels\n',
#  '},\n',
#  '{ // frame 1\n',
#  '0x3186, 0x8410, 0x738E, 0x3186, 0x0000, 0x0000, 0x3186, 0x3186, 0x8410, 0xC618, 0xA514, 0xF79E, 0xC618, 0x1082, 0x8410, 0x8410,   // 0x0010 (16) pixels\n',
# ...

# %%
newfilepath = imgpath / '../nkr.h'

# %%
textstr = ''.join(text)

# %%
textstr
# Out:
# 'const unsigned short n[][64] = {\n{ // frame 0\n0x0000, 0x0000, 0x0000, 0xE71C, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0xFFFF, 0xE71C, 0x3186, 0x0000, 0x0000,   // 0x0010 (16) pixels\n0x0000, 0x0000, 0x0000, 0xFFFF, 0x630C, 0xF79E, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x630C, 0x0000, 0xFFFF, 0x0000, 0x0000,   // 0x0020 (32) pixels\n0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0xFFFF, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0xFFFF, 0x0000, 0x0000,   // 0x0030 (48) pixels\n0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0xFFFF, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0x0000, 0xE71C, 0x0000, 0x0000,   // 0x0040 (64) pixels\n},\n{ // frame 1\n0x3186, 0x8410, 0x738E, 0x3186, 0x0000, 0x0000, 0x3186, 0x3186, 0x8410, 0xC618, 0xA514, 0xF79E, 0xC618, 0x1082, 0x8410, 0x8410,   // 0x0010 (16) pixels\n0x8410, 0x8410, 0x0000, 0x1082, 0xA514, 0xF79E, 0x9492, 0x8410, 0x8410, 0x8410, 0x0000, 0x0000, 0x0000, 0xB596, 0xFFFF, 0x8410,   // 0x0020 (32) pixels\n0x8410, 0x841
# ...

# %%
newfilepath.write_text(textstr)
# Out:
# 9468

# %%
for f in imgpath.ls():
    if f.suffix == '.c':
        fsorted[int(f.stem[-5:])] = f
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 5
#       3 for f in imgpath.ls():
#       4     if f.suffix == '.c':
# ----> 5         fsorted[int(f.stem[-5:])] = f
#
# IndexError: list assignment index out of range
